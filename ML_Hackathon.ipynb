# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_train = pd.read_csv("TD-2.csv")
data_test = pd.read_csv("TeD-1.csv")
data_train.head()
# Out:
#    clientid_cr  ... conversion_fraud
# 0        75694  ...             True
# 1        75694  ...             True
# 2        75694  ...             True
# 3        75694  ...             True
# 4        30431  ...             True
#
# [5 rows x 33 columns]

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 945 entries, 0 to 944
# Data columns (total 33 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   clientid_cr                    945 non-null    int64
#  1   imprid_cr                      945 non-null    object
#  2   adslotdimid_cr                 945 non-null    int64
#  3   algo_cr                        945 non-null    int64
#  4   clickbid_cr                    669 non-null    float64
#  5   itemcolumbiaid_cr              945 non-null    int64
#  6   itemid_cr                      945 non-null    int64
#  7   position_cr                    945 non-null    int64
#  8   pubclientid_cr                 945 non-null    int64
#  9   siteId_cr                      945 non-null    int64
#  10  templateid_cr                  858 non-null    float64
#  11  goalid_cr                      945 non-null    int64
# ...

# %%
data_train['clientid_cr'].unique()
# Out:
# array([75694, 30431, 82122, 77339, 86530,  1465,  7750,   802, 78510,
#        85572, 86321, 66066, 32847,  7063, 25470, 77713, 67368, 86495,
#        29892,  2139, 31365,  3180,  8895, 83515, 64588, 84618, 86431,
#        43386, 24075, 66839, 70668, 77616, 67615, 26329, 85524, 77274,
#        51483, 78614, 69398, 70900, 12510, 43051, 28602, 85774, 76280,
#        64731, 85007,  2380, 16664, 35702, 17232,  2060, 86555, 70491,
#        77538,  1518])

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
data_click_log = pd.read_csv("/content/drive/MyDrive/data/click_log.csv")

# %%
data_click_log.head()
# Out:
#    Unnamed: 0                                      imprId  ... imprUserId  optout
# 0           0  72efd138-0f6a-4aed-bd3f-9bdd70c0e869-1sjts  ...        NaN     NaN
# 1           0   210a7e16-6783-46a5-9246-c635db091490-3qpg  ...        NaN     NaN
# 2           0  179d3fbb-3e10-435d-851d-f65029ef2eb4-10ntc  ...        NaN     NaN
# 3           0  79ce617b-88bf-46db-8069-6c892df6a306-1sjo8  ...        NaN     NaN
# 4           0  c8f88058-af7e-4284-8c88-2410d94f82e3-1sjo8  ...        NaN     NaN
#
# [5 rows x 55 columns]

# %%
final_data = pd.read_csv('final.csv')
final_data.head(344)
# Out:
#      clientid_cr  ...                                       devTypeDimId
# 0        75694.0  ...  182720    202038.0\nName: devTypeDimId, dtype:...
# 1        75694.0  ...  182541    202038.0\n182772    202038.0\nName: ...
# 2        75694.0  ...  182846    202038.0\nName: devTypeDimId, dtype:...
# 3        75694.0  ...  182975    202038.0\nName: devTypeDimId, dtype:...
# 4        30431.0  ...   101239   NaN\nName: devTypeDimId, dtype: float64
# ..           ...  ...                                                ...
# 339      75694.0  ...  182517    202038.0\nName: devTypeDimId, dtype:...
# 340      29892.0  ...   100392   NaN\nName: devTypeDimId, dtype: float64
# 341      83515.0  ...  233162    196041.0\nName: devTypeDimId, dtype:...
# 342      64588.0  ...  135342    0.0\nName: devTypeDimId, dtype: float64
# 343      25470.0  ...     Series([], Name: devTypeDimId, dtype: float64)
#
# [344 rows x 37 columns]

# %%
# for i in range()
# t = int(str(final_data['itmClmbLId'][:]).split()[1])
# print(t.shape)
# final_data['itmClmbLId']
# t = final_data
# x = t['itmClmbLId'][1].split()[:]
# print(x)
# t['itmClmbLId'] = t['itmClmbLId']).split()[1].astype(int)
# t['itmClmbLId'] = t['itmClmbLId'].astype(str)
# t['itmClmbLId'][0] = t['itmClmbLId'][0].split()[1]

  # t.new.iloc[i] = int(str(final_data['itmClmbLId'][i]).split()[1])
# t['itmClmbLId'] = t['itmClmbLId'].apply(lambda x: int(str(x).split()[1]))
# print(str((final_data['itmClmbLId'][0]).split()[:]))
# print("hello")
# x = list((final_data['itmClmbLId'][343]).split()[:])
# print(x[1])
# def hello(x):

# for i in range(344):
#   x = []
#   x = list((final_data['itmClmbLId'][i]).split()[:])
#   print(x[1])
#   if x[1] == "Name:":
#     pass
#   else:
#     t['itmClmbLId'] = t['itmClmbLId'].apply(lambda x: list(str(x).split()[1]))
# print((final_data['itmClmbLId'][1]).split()[:])
# for i in range(1):
#   x = t['itmClmbLId'][i].split()[:]
  # if x[1] == 'Name:':
  #   pass
  # else:
  #   t['itmClmbLId'] = t['itmClmbLId'].apply(lambda x : x.split()[1])
  #print(x)

t = pd.read_csv('/content/final.csv')
j = 0
k = 0
z = []
for i in range(t.shape[0]):
  x = (t['itmClmbLId'][i].split()[:])
  if x[1] == 'Name:':
    j = j + 1
    z.append(i)
    t.loc[i, 'itmClmbLId'] = np.nan
  else:
    k = k + 1
    u = (t['itmClmbLId'][i].split()[:])
    # df.replace(to_replace =["Boston Celtics", "Texas"], 
    #                         value ="Omega Warrior")
    # df.loc[2, 'D1'] = 32
    t.loc[i, 'itmClmbLId'] = int(u[1])
print(j)
print(z)   
print(k)
# Out:
# 131
# [94, 116, 125, 126, 129, 134, 143, 145, 147, 159, 162, 164, 168, 177, 180, 185, 186, 192, 194, 211, 223, 232, 239, 243, 244, 251, 259, 261, 264, 265, 268, 276, 297, 300, 307, 312, 313, 314, 316, 320, 323, 343, 347, 348, 352, 367, 373, 379, 384, 389, 410, 413, 416, 419, 420, 421, 425, 428, 429, 433, 437, 442, 443, 448, 453, 466, 487, 493, 500, 506, 520, 525, 527, 556, 557, 568, 586, 598, 601, 602, 603, 611, 624, 629, 644, 647, 649, 656, 657, 660, 666, 674, 685, 687, 696, 699, 701, 718, 719, 740, 742, 745, 754, 757, 759, 775, 776, 777, 787, 790, 817, 818, 819, 822, 827, 833, 842, 847, 856, 858, 873, 883, 890, 895, 905, 907, 913, 915, 923, 928, 933]
# 803

# %%
t.head(344)
# Out:
#      clientid_cr  ...                                       devTypeDimId
# 0        75694.0  ...  182720    202038.0\nName: devTypeDimId, dtype:...
# 1        75694.0  ...  182541    202038.0\n182772    202038.0\nName: ...
# 2        75694.0  ...  182846    202038.0\nName: devTypeDimId, dtype:...
# 3        75694.0  ...  182975    202038.0\nName: devTypeDimId, dtype:...
# 4        30431.0  ...   101239   NaN\nName: devTypeDimId, dtype: float64
# ..           ...  ...                                                ...
# 339      75694.0  ...  182517    202038.0\nName: devTypeDimId, dtype:...
# 340      29892.0  ...   100392   NaN\nName: devTypeDimId, dtype: float64
# 341      83515.0  ...  233162    196041.0\nName: devTypeDimId, dtype:...
# 342      64588.0  ...  135342    0.0\nName: devTypeDimId, dtype: float64
# 343      25470.0  ...     Series([], Name: devTypeDimId, dtype: float64)
#
# [344 rows x 37 columns]

# %%
t = pd.read_csv('/content/final.csv')
x = (t['itmClmbLId'][0].split()[:])
print(type(int(x[1])))
print(int(x[1]))
# Out:
# <class 'int'>
# 5488088

# %%
t = pd.read_csv('/content/final.csv')
x = (t['devTypeDimId'][343].split()[:])
print((float(x[1])))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-156-1fc860acbd88> in <module>()
#       1 t = pd.read_csv('/content/final.csv')
#       2 x = (t['devTypeDimId'][343].split()[:])
# ----> 3 print((float(x[1])))
#
# ValueError: could not convert string to float: 'Name:'

# %%
final_data.head()
# Out:
#    clientid_cr  ...                                       devTypeDimId
# 0      75694.0  ...  182720    202038.0\nName: devTypeDimId, dtype:...
# 1      75694.0  ...  182541    202038.0\n182772    202038.0\nName: ...
# 2      75694.0  ...  182846    202038.0\nName: devTypeDimId, dtype:...
# 3      75694.0  ...  182975    202038.0\nName: devTypeDimId, dtype:...
# 4      30431.0  ...   101239   NaN\nName: devTypeDimId, dtype: float64
#
# [5 rows x 37 columns]

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Data columns (total 37 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   clientid_cr                    933 non-null    float64
#  1   imprid_cr                      933 non-null    object
#  2   adslotdimid_cr                 933 non-null    float64
#  3   algo_cr                        933 non-null    float64
#  4   clickbid_cr                    657 non-null    float64
#  5   itemcolumbiaid_cr              933 non-null    float64
#  6   itemid_cr                      933 non-null    float64
#  7   position_cr                    933 non-null    float64
#  8   pubclientid_cr                 933 non-null    float64
#  9   siteId_cr                      933 non-null    float64
#  10  templateid_cr                  846 non-null    float64
#  11  goalid_cr                      933 non-null    float64
# ...

# %%
final_data.columns
# Out:
# Index(['clientid_cr', 'imprid_cr', 'adslotdimid_cr', 'algo_cr', 'clickbid_cr',
#        'itemcolumbiaid_cr', 'itemid_cr', 'position_cr', 'pubclientid_cr',
#        'siteId_cr', 'templateid_cr', 'goalid_cr', 'adLogType_cr',
#        'pricingtype_cr', 'osId_cr', 'browserId_cr', 'cityId_cr', 'stateId_cr',
#        'modelDimId_cr', 'lookUpFrom_cr', 'connTypeDimId_cr', 'ispDimId_cr',
#        'countryDimId_cr', 'goalTypeId_cr', 'conversionDurationInMillis_cr',
#        'osVerDimId_cr', 'uuidSource_cr', 'geoGrpDimId_cr', 'stateGrpDimId_cr',
#        'usrClusterId_cr', 'cityGrpDimId_cr', 'siteClusterIds_cr',
#        'conversion_fraud', 'clickIp', 'crtd', 'itmClmbLId', 'devTypeDimId'],
#       dtype='object')

# %%
final_data.isna().sum()
# Out:
# clientid_cr                        1
# imprid_cr                          1
# adslotdimid_cr                     1
# algo_cr                            1
# clickbid_cr                      277
# itemcolumbiaid_cr                  1
# itemid_cr                          1
# position_cr                        1
# pubclientid_cr                     1
# siteId_cr                          1
# templateid_cr                     88
# goalid_cr                          1
# adLogType_cr                       1
# pricingtype_cr                     1
# osId_cr                            2
# browserId_cr                       2
# cityId_cr                          1
# stateId_cr                         1
# modelDimId_cr                      2
# lookUpFrom_cr                      1
# connTypeDimId_cr                   1
# ispDimId_cr                        1
# countryDimId_cr                    1
# goalTypeId_cr                      1
# conversionDurationInMillis_cr      1
# ...

# %%
print(len(final_data.clientid_cr.unique()))
print(len(final_data.imprid_cr.unique()))
print(len(final_data.adslotdimid_cr.unique()))
print(len(final_data.algo_cr.unique()))
print(len(final_data.clickbid_cr.unique()))
print(len(final_data.itemcolumbiaid_cr.unique()))
print(len(final_data.itemid_cr.unique()))
print(len(final_data.position_cr.unique()))
print(len(final_data.pubclientid_cr.unique()))
print(len(final_data.siteId_cr.unique()))
print(len(final_data.templateid_cr.unique()))
print(len(final_data.goalid_cr.unique()))
print(len(final_data.adLogType_cr.unique()))
print(len(final_data.pricingtype_cr.unique()))
print(len(final_data.osId_cr.unique()))
print(len(final_data.browserId_cr.unique()))
print(len(final_data.cityId_cr.unique()))
print(len(final_data.stateId_cr.unique()))
print(len(final_data.modelDimId_cr.unique()))
print(len(final_data.lookUpFrom_cr.unique()))
print(len(final_data.connTypeDimId_cr.unique()))
print(len(final_data.ispDimId_cr.unique()))
print(len(final_data.countryDimId_cr.unique()))
print(len(final_data.goalTypeId_cr.unique()))
print(len(final_data.conversionDurationInMillis_cr.unique()))
print(len(final_data.osVerDimId_cr.unique()))
print(len(final_data.uuidSource_cr.unique()))
print(len(final_data.geoGrpDimId_cr.unique()))
print(len(final_data.stateGrpDimId_cr .unique()))
print(len(final_data.usrClusterId_cr.unique()))
print(len(final_data.cityGrpDimId_cr.unique()))
print(len(final_data.siteClusterIds_cr.unique()))
print(len(final_data.conversion_fraud.unique()))
print(len(final_data.clickIp.unique()))
print(len(final_data.crtd.unique()))
print(len(final_data.itmClmbLId.unique()))
print(len(final_data.devTypeDimId.unique()))
# Out:
# 57
# 934
# 191
# 13
# 59
# 125
# 174
# 167
# 43
# 77
# 137
# 57
# 3
# 4
# 16
# 11
# 83
# 46
# 23
# 3
# 10
# 137
# 10
# 2
# 913
# 33
# 7
# 8
# 9
# 196
# 7
# 55
# 3
# 804
# 2
# 804
# 804

# %% [markdown]
# Function for One Hot Encoding

# %%
print(final_data.dtypes)
# Out:
# clientid_cr                      float64
# imprid_cr                         object
# adslotdimid_cr                   float64
# algo_cr                          float64
# clickbid_cr                      float64
# itemcolumbiaid_cr                float64
# itemid_cr                        float64
# position_cr                      float64
# pubclientid_cr                   float64
# siteId_cr                        float64
# templateid_cr                    float64
# goalid_cr                        float64
# adLogType_cr                     float64
# pricingtype_cr                   float64
# osId_cr                          float64
# browserId_cr                     float64
# cityId_cr                        float64
# stateId_cr                       float64
# modelDimId_cr                    float64
# lookUpFrom_cr                    float64
# connTypeDimId_cr                  object
# ispDimId_cr                      float64
# countryDimId_cr                  float64
# ...

# %%
final_data["clientid_cr"] = final_data["clientid_cr"].astype(str)
print(final_data.dtypes)
# Out:
# clientid_cr                       object
# imprid_cr                         object
# adslotdimid_cr                   float64
# algo_cr                          float64
# clickbid_cr                      float64
# itemcolumbiaid_cr                float64
# itemid_cr                        float64
# position_cr                      float64
# pubclientid_cr                   float64
# siteId_cr                        float64
# templateid_cr                    float64
# goalid_cr                        float64
# adLogType_cr                     float64
# pricingtype_cr                   float64
# osId_cr                          float64
# browserId_cr                     float64
# cityId_cr                        float64
# stateId_cr                       float64
# modelDimId_cr                    float64
# lookUpFrom_cr                    float64
# connTypeDimId_cr                  object
# ispDimId_cr                      float64
# countryDimId_cr                  float64
# ...

# %%
def encode_and_bind(original_dataframe, feature_to_encode):
    dummies = pd.get_dummies(original_dataframe[[feature_to_encode]])
    res = pd.concat([original_dataframe, dummies], axis=1)
    return(res)

# %%
r = encode_and_bind(final_data,"clientid_cr")

# %%
r.info()
r.drop('clientid_cr',axis=1,inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Data columns (total 94 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   clientid_cr                    934 non-null    object
#  1   imprid_cr                      933 non-null    object
#  2   adslotdimid_cr                 933 non-null    float64
#  3   algo_cr                        933 non-null    float64
#  4   clickbid_cr                    657 non-null    float64
#  5   itemcolumbiaid_cr              933 non-null    float64
#  6   itemid_cr                      933 non-null    float64
#  7   position_cr                    933 non-null    float64
#  8   pubclientid_cr                 933 non-null    float64
#  9   siteId_cr                      933 non-null    float64
#  10  templateid_cr                  846 non-null    float64
#  11  goalid_cr                      933 non-null    float64
# ...

# %%
r.drop('imprid_cr',axis=1,inplace=True)
r["adslotdimid_cr"] = r["adslotdimid_cr"].astype(str)
print(r.dtypes)
# Out:
# adslotdimid_cr          object
# algo_cr                float64
# clickbid_cr            float64
# itemcolumbiaid_cr      float64
# itemid_cr              float64
#                         ...
# clientid_cr_86495.0      uint8
# clientid_cr_86530.0      uint8
# clientid_cr_86555.0      uint8
# clientid_cr_8895.0       uint8
# clientid_cr_nan          uint8
# Length: 92, dtype: object

# %%
r = encode_and_bind(r,"adslotdimid_cr")
r.info()
r.drop('adslotdimid_cr',axis=1,inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Columns: 283 entries, adslotdimid_cr to adslotdimid_cr_nan
# dtypes: float64(27), object(8), uint8(248)
# memory usage: 481.7+ KB

# %%
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Columns: 282 entries, algo_cr to adslotdimid_cr_nan
# dtypes: float64(27), object(7), uint8(248)
# memory usage: 474.4+ KB

# %%
r["algo_cr"] = r["algo_cr"].astype(str)
r = encode_and_bind(r,"algo_cr")
r.drop('algo_cr',axis=1,inplace=True)
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Columns: 294 entries, clickbid_cr to algo_cr_nan
# dtypes: float64(26), object(7), uint8(261)
# memory usage: 479.0+ KB

# %%
r["clickbid_cr"] = r["clickbid_cr"].astype(str)
r = encode_and_bind(r,"clickbid_cr")
r.drop('clickbid_cr',axis=1,inplace=True)
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Columns: 352 entries, itemcolumbiaid_cr to clickbid_cr_nan
# dtypes: float64(25), object(7), uint8(320)
# memory usage: 525.5+ KB

# %%
r["itemcolumbiaid_cr"] = r["itemcolumbiaid_cr"].astype(str)
r = encode_and_bind(r,"itemcolumbiaid_cr")
r.drop('itemcolumbiaid_cr',axis=1,inplace=True)
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Columns: 476 entries, itemid_cr to itemcolumbiaid_cr_nan
# dtypes: float64(24), object(7), uint8(445)
# memory usage: 632.2+ KB

# %%
r["itemid_cr"] = r["itemid_cr"].astype(str)
r = encode_and_bind(r,"itemid_cr")
r.drop('itemid_cr',axis=1,inplace=True)
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Columns: 649 entries, position_cr to itemid_cr_nan
# dtypes: float64(23), object(7), uint8(619)
# memory usage: 783.6+ KB

# %%
r["position_cr"] = r["position_cr"].astype(str)
r = encode_and_bind(r,"position_cr")
r.drop('position_cr',axis=1,inplace=True)
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Columns: 815 entries, pubclientid_cr to position_cr_nan
# dtypes: float64(22), object(7), uint8(786)
# memory usage: 928.7+ KB

# %%
r["pubclientid_cr"] = r["pubclientid_cr"].astype(str)
r = encode_and_bind(r,"pubclientid_cr")
r.drop('pubclientid_cr',axis=1,inplace=True)
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Columns: 857 entries, siteId_cr to pubclientid_cr_nan
# dtypes: float64(21), object(7), uint8(829)
# memory usage: 960.6+ KB

# %%
r["siteId_cr"] = r["siteId_cr"].astype(str)
r = encode_and_bind(r,"siteId_cr")
r.drop('siteId_cr',axis=1,inplace=True)
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Columns: 933 entries, templateid_cr to siteId_cr_nan
# dtypes: float64(20), object(7), uint8(906)
# memory usage: 1023.5+ KB

# %%
r["templateid_cr"] = r["templateid_cr"].astype(str)
r = encode_and_bind(r,"templateid_cr")
r.drop('templateid_cr',axis=1,inplace=True)
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Columns: 1069 entries, goalid_cr to templateid_cr_nan
# dtypes: float64(19), object(7), uint8(1043)
# memory usage: 1.1+ MB

# %%
r["goalid_cr"] = r["goalid_cr"].astype(str)
r = encode_and_bind(r,"goalid_cr")
r.drop('goalid_cr',axis=1,inplace=True)
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Columns: 1125 entries, adLogType_cr to goalid_cr_nan
# dtypes: float64(18), object(7), uint8(1100)
# memory usage: 1.2+ MB

# %%
r["adLogType_cr"] = r["adLogType_cr"].astype(str)
r = encode_and_bind(r,"adLogType_cr")
r.drop('adLogType_cr',axis=1,inplace=True)
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Columns: 1127 entries, pricingtype_cr to adLogType_cr_nan
# dtypes: float64(17), object(7), uint8(1103)
# memory usage: 1.2+ MB

# %%
r["pricingtype_cr"] = r["pricingtype_cr"].astype(str)
r = encode_and_bind(r,"pricingtype_cr")
r.drop('pricingtype_cr',axis=1,inplace=True)
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Columns: 1130 entries, osId_cr to pricingtype_cr_nan
# dtypes: float64(16), object(7), uint8(1107)
# memory usage: 1.2+ MB

# %%
r["osId_cr"] = r["osId_cr"].astype(str)
r = encode_and_bind(r,"osId_cr")
r.drop('osId_cr',axis=1,inplace=True)
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Columns: 1145 entries, browserId_cr to osId_cr_nan
# dtypes: float64(15), object(7), uint8(1123)
# memory usage: 1.2+ MB

# %%
r["browserId_cr"] = r["browserId_cr"].astype(str)
r = encode_and_bind(r,"browserId_cr")
r.drop('browserId_cr',axis=1,inplace=True)
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Columns: 1155 entries, cityId_cr to browserId_cr_nan
# dtypes: float64(14), object(7), uint8(1134)
# memory usage: 1.2+ MB

# %%
r["cityId_cr"] = r["cityId_cr"].astype(str)
r = encode_and_bind(r,"cityId_cr")
r.drop('cityId_cr',axis=1,inplace=True)
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Columns: 1237 entries, stateId_cr to cityId_cr_nan
# dtypes: float64(13), object(7), uint8(1217)
# memory usage: 1.2+ MB

# %%
r["stateId_cr"] = r["stateId_cr"].astype(str)
r = encode_and_bind(r,"stateId_cr")
r.drop('stateId_cr',axis=1,inplace=True)
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Columns: 1282 entries, modelDimId_cr to stateId_cr_nan
# dtypes: float64(12), object(7), uint8(1263)
# memory usage: 1.3+ MB

# %%
r["modelDimId_cr"] = r["modelDimId_cr"].astype(str)
r = encode_and_bind(r,"modelDimId_cr")
r.drop('modelDimId_cr',axis=1,inplace=True)
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Columns: 1304 entries, lookUpFrom_cr to modelDimId_cr_nan
# dtypes: float64(11), object(7), uint8(1286)
# memory usage: 1.3+ MB

# %%
r["lookUpFrom_cr"] = r["lookUpFrom_cr"].astype(str)
r = encode_and_bind(r,"lookUpFrom_cr")
r.drop('lookUpFrom_cr',axis=1,inplace=True)
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Columns: 1306 entries, connTypeDimId_cr to lookUpFrom_cr_nan
# dtypes: float64(10), object(7), uint8(1289)
# memory usage: 1.3+ MB

# %%
r["connTypeDimId_cr"] = r["connTypeDimId_cr"].astype(str)
r = encode_and_bind(r,"connTypeDimId_cr")
r.drop('connTypeDimId_cr',axis=1,inplace=True)
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Columns: 1315 entries, ispDimId_cr to connTypeDimId_cr_nan
# dtypes: float64(10), object(6), uint8(1299)
# memory usage: 1.3+ MB

# %%
r["ispDimId_cr"] = r["ispDimId_cr"].astype(str)
r = encode_and_bind(r,"ispDimId_cr")
r.drop('ispDimId_cr',axis=1,inplace=True)
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Columns: 1451 entries, countryDimId_cr to ispDimId_cr_nan
# dtypes: float64(9), object(6), uint8(1436)
# memory usage: 1.4+ MB

# %%
r["countryDimId_cr"] = r["countryDimId_cr"].astype(str)
r = encode_and_bind(r,"countryDimId_cr")
r.drop('countryDimId_cr',axis=1,inplace=True)
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Columns: 1460 entries, goalTypeId_cr to countryDimId_cr_nan
# dtypes: float64(8), object(6), uint8(1446)
# memory usage: 1.4+ MB

# %%
r.drop('goalTypeId_cr',axis=1,inplace=True)

# %%
r['conversionDurationInMillis_cr'].fillna(r['conversionDurationInMillis_cr'].mean(),inplace = True)

# %%
r["osVerDimId_cr"] = r["osVerDimId_cr"].astype(str)
r = encode_and_bind(r,"osVerDimId_cr")
r.drop('osVerDimId_cr',axis=1,inplace=True)
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Columns: 1491 entries, conversionDurationInMillis_cr to osVerDimId_cr_nan
# dtypes: float64(6), object(6), uint8(1479)
# memory usage: 1.4+ MB

# %%
r["uuidSource_cr"] = r["uuidSource_cr"].astype(str)
r = encode_and_bind(r,"uuidSource_cr")
r.drop('uuidSource_cr',axis=1,inplace=True)
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Columns: 1497 entries, conversionDurationInMillis_cr to uuidSource_cr_nan
# dtypes: float64(5), object(6), uint8(1486)
# memory usage: 1.4+ MB

# %%
r["geoGrpDimId_cr"] = r["geoGrpDimId_cr"].astype(str)
r = encode_and_bind(r,"geoGrpDimId_cr")
r.drop('geoGrpDimId_cr',axis=1,inplace=True)
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Columns: 1504 entries, conversionDurationInMillis_cr to geoGrpDimId_cr_nan
# dtypes: float64(4), object(6), uint8(1494)
# memory usage: 1.4+ MB

# %%
r["stateGrpDimId_cr"] = r["stateGrpDimId_cr"].astype(str)
r = encode_and_bind(r,"stateGrpDimId_cr")
r.drop('stateGrpDimId_cr',axis=1,inplace=True)
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Columns: 1512 entries, conversionDurationInMillis_cr to stateGrpDimId_cr_nan
# dtypes: float64(3), object(6), uint8(1503)
# memory usage: 1.4+ MB

# %%
r.drop('usrClusterId_cr',axis=1,inplace=True)

# %%
r.drop('cityGrpDimId_cr',axis=1,inplace=True)
r.drop('siteClusterIds_cr',axis=1,inplace=True)

# %%
r.drop('clickIp',axis=1,inplace=True)

# %%
r.drop('crtd',axis=1,inplace=True)

# %%
# t = pd.read_csv('/content/final.csv')
j = 0
k = 0
z = []
for i in range(r.shape[0]):
  x = (r['itmClmbLId'][i].split()[:])
  if x[1] == 'Name:':
    j = j + 1
    z.append(i)
    r.loc[i, 'itmClmbLId'] = np.nan
  else:
    k = k + 1
    u = (r['itmClmbLId'][i].split()[:])
    # df.replace(to_replace =["Boston Celtics", "Texas"], 
    #                         value ="Omega Warrior")
    # df.loc[2, 'D1'] = 32
    r.loc[i, 'itmClmbLId'] = int(u[1])
print(j)
print(z)   
print(k)
# Out:
# 131
# [94, 116, 125, 126, 129, 134, 143, 145, 147, 159, 162, 164, 168, 177, 180, 185, 186, 192, 194, 211, 223, 232, 239, 243, 244, 251, 259, 261, 264, 265, 268, 276, 297, 300, 307, 312, 313, 314, 316, 320, 323, 343, 347, 348, 352, 367, 373, 379, 384, 389, 410, 413, 416, 419, 420, 421, 425, 428, 429, 433, 437, 442, 443, 448, 453, 466, 487, 493, 500, 506, 520, 525, 527, 556, 557, 568, 586, 598, 601, 602, 603, 611, 624, 629, 644, 647, 649, 656, 657, 660, 666, 674, 685, 687, 696, 699, 701, 718, 719, 740, 742, 745, 754, 757, 759, 775, 776, 777, 787, 790, 817, 818, 819, 822, 827, 833, 842, 847, 856, 858, 873, 883, 890, 895, 905, 907, 913, 915, 923, 928, 933]
# 803

# %%
r['itmClmbLId'].isna().sum()
# Out:
# 131

# %%
r.itmClmbLId.fillna(r['itmClmbLId'].mean(), inplace=True)

# %%
# t = pd.read_csv('/content/final.csv')
j = 0
k = 0
z = []
for i in range(r.shape[0]):
  x = (r['devTypeDimId'][i].split()[:])
  if x[1] == 'Name:':
    j = j + 1
    z.append(i)
    r.loc[i, 'devTypeDimId'] = np.nan
  else:
    k = k + 1
    u = (r['devTypeDimId'][i].split()[:])
    # df.replace(to_replace =["Boston Celtics", "Texas"], 
    #                         value ="Omega Warrior")
    # df.loc[2, 'D1'] = 32
    r.loc[i, 'devTypeDimId'] = (float(u[1]))  
    
print(j)
print(z)   
print(k)
# Out:
# 131
# [94, 116, 125, 126, 129, 134, 143, 145, 147, 159, 162, 164, 168, 177, 180, 185, 186, 192, 194, 211, 223, 232, 239, 243, 244, 251, 259, 261, 264, 265, 268, 276, 297, 300, 307, 312, 313, 314, 316, 320, 323, 343, 347, 348, 352, 367, 373, 379, 384, 389, 410, 413, 416, 419, 420, 421, 425, 428, 429, 433, 437, 442, 443, 448, 453, 466, 487, 493, 500, 506, 520, 525, 527, 556, 557, 568, 586, 598, 601, 602, 603, 611, 624, 629, 644, 647, 649, 656, 657, 660, 666, 674, 685, 687, 696, 699, 701, 718, 719, 740, 742, 745, 754, 757, 759, 775, 776, 777, 787, 790, 817, 818, 819, 822, 827, 833, 842, 847, 856, 858, 873, 883, 890, 895, 905, 907, 913, 915, 923, 928, 933]
# 803

# %%
r['devTypeDimId'].isna().sum()
# Out:
# 195

# %%
print(len(final_data.devTypeDimId.unique()))
r.devTypeDimId.fillna(r['devTypeDimId'].mean(), inplace=True)
# Out:
# 804

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
r.isna().sum()
# Out:
# conversionDurationInMillis_cr         0
# conversion_fraud                      1
# itmClmbLId                            0
# devTypeDimId                          0
# clientid_cr_12510.0                   0
# clientid_cr_1465.0                    0
# clientid_cr_1518.0                    0
# clientid_cr_16664.0                   0
# clientid_cr_17232.0                   0
# clientid_cr_2060.0                    0
# clientid_cr_2139.0                    0
# clientid_cr_2380.0                    0
# clientid_cr_24075.0                   0
# clientid_cr_25470.0                   0
# clientid_cr_26329.0                   0
# clientid_cr_28602.0                   0
# clientid_cr_29892.0                   0
# clientid_cr_30431.0                   0
# clientid_cr_31365.0                   0
# clientid_cr_3180.0                    0
# clientid_cr_32847.0                   0
# clientid_cr_35702.0                   0
# clientid_cr_43051.0                   0
# ...

# %%
r.to_csv("final_data.csv")
